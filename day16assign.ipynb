# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
columns = ['gender', 'race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course', 'math score', 'reading score',
       'writing score']
columns
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %%
sns.relplot(x = 'race/ethnicity', y = 'math score', data = df, hue = 'gender', style = 'race/ethnicity')

# %%
sns.relplot(x = 'race/ethnicity', y = 'math score', data = df, hue = 'gender', style = 'race/ethnicity', col='test preparation course')

# %%
sns.relplot(x = 'race/ethnicity', y = 'math score', data = df, hue = 'gender', style = 'race/ethnicity', col = 'test preparation course', kind='line')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.catplot(x = 'gender', y = 'race/ethnicity', data = df, hue = 'gender', kind = 'bar')

# %%
sns.catplot(x = 'gender', y = 'race/ethnicity', data = df, hue = 'gender', kind = 'swarm')

# %%
sns.catplot(x = 'gender', y = 'race/ethnicity', data = df, hue = 'gender', kind = 'violin')

# %%
sns.scatterplot(x='math score', y='writing score', data=df, hue='gender')
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
sns.barplot(x='parental level of education', y='reading score', data=df, hue='gender')
# Out:
# <Axes: xlabel='parental level of education', ylabel='reading score'>

# %%
sns.barplot(x='race/ethnicity', y='reading score', data=df, hue='gender')
plt.title('READING')
plt.ylabel('Reading Score')
plt.xlabel('Race/Ethnicity')
plt.show()

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
label = list(df['race/ethnicity'].value_counts().keys())
label
# Out:
# ['group C', 'group D', 'group B', 'group E', 'group A']

# %%
value = list(df['race/ethnicity'].value_counts().values)
value
# Out:
# [319, 262, 190, 140, 89]

# %%
plt.bar(label, value)
plt.xticks(rotation = 0)
plt.title('GRAPH')
plt.ylabel('score')
plt.xlabel('race/ethnicity')      #rotates the labels mentioned under
plt.show()

# %%
plt.pie(value, labels=label, wedgeprops= {'edgecolor':'k'})    #k is short for black
plt.show()

# %%
list1 = [0.1,0.1,0.1,0.2,0.1]
sns.set(rc={'figure.figsize':(4,4)})
plt.pie(value, labels=label, wedgeprops= {'edgecolor':'k'}, explode=list1, autopct='%1.2f%%', shadow=True)
plt.title('pie chart')
plt.show()

# %%
sns.catplot(x='race/ethnicity', y='math score', data=df, hue='gender', kind='bar')

# %%
sns.catplot(x='race/ethnicity', y='math score', data=df, hue='gender', kind='bar', col='gender')

# %%
sns.catplot(x='lunch', y='writing score', data=df, hue='race/ethnicity', kind='bar')

# %%
sns.catplot(x='lunch', y='writing score', data=df, hue='race/ethnicity', kind='bar', col='gender')

# %%
sns.catplot(x='lunch', y='writing score', data=df, hue='race/ethnicity', kind='bar', row='gender')

# %%
sns.catplot(x='race/ethnicity', y='math score', data=df, hue='gender')

# %%
sns.relplot(x='race/ethnicity', y='math score', data=df, hue='gender', kind='line')

# %%
sns.boxplot(df['math score'])
# Out:
# <Axes: ylabel='math score'>

# %%
sns.boxplot(df['reading score'])
# Out:
# <Axes: ylabel='reading score'>
